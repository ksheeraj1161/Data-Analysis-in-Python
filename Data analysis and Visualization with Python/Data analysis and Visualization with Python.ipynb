# %% [markdown]
# # Data analysis and Visualization with Python
# Pandas is one of those packages, and makes importing and analyzing data much easier.

# %% [markdown]
# # Creating A DataFrame in Pandas
# Creation of dataframe is done by passing multiple Series into the DataFrame class using pd.Series method.

# %%
import pandas as pd
# assigning two series to s1 and s2
s1 = pd.Series([1,2])
s2 = pd.Series(["ksheeraj", "Hiranmayee"])
# framing series objects into data
df = pd.DataFrame([s1,s2])
# show the data frame
df
# Out:
#           0           1
# 0         1           2
# 1  ksheeraj  Hiranmayee

# %%
# data framing in another way
# taking index and column values
dframe = pd.DataFrame([[1,2],["ksheeraj", "Hiranmayee"]],
		index=["r1", "r2"],
		columns=["c1", "c2"])
dframe
# Out:
#           c1          c2
# r1         1           2
# r2  ksheeraj  Hiranmayee

# %%
# framing in another way
# dict-like container
dframe = pd.DataFrame({
		"c1": [1, "ksheeraj"],
		"c2": [2, "Hiranmayee"]})
dframe
# Out:
#          c1          c2
# 0         1           2
# 1  ksheeraj  Hiranmayee

# %% [markdown]
# # Importing Data with Pandas
#
# The data is stored as a comma-separated values, or csv, file, where each row is separated by a new line, and each column by a comma (,). In order to be able to work with the data in Python, it is needed to read the csv file into a Pandas DataFrame. A DataFrame is a way to represent and work with tabular data.

# %%
# Import the pandas library, renamed as pd
import pandas as pd

# Read IND_data.csv into a DataFrame, assigned to df
df = pd.read_csv("C:/Users/kandr/Desktop/PYTHON/Programming/Data Analysis/Data analysis and Visualization with Python/world_cup_comparisons.csv")

# Prints the first 5 rows of a DataFrame as default
df.head()
# Out:
#            player  season       team  goals_z  xg_z  crosses_z  boxtouches_z  \
# 0  Cristian Pavón    2018  Argentina    -0.42 -0.55       0.08         -0.24
# 1  Eduardo Salvio    2018  Argentina    -0.42 -0.50      -0.51          0.64
# 2      Enzo Pérez    2018  Argentina    -0.42  0.11      -0.51         -0.69
# 3  Federico Fazio    2018  Argentina    -0.42 -0.59      -0.51         -0.69
# 4   Franco Armani    2018  Argentina    -0.42 -0.59      -0.51         -0.80
#
#    passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# 0     -0.61         -0.72      -0.05        0.15       0.30            -0.79
# 1      0.02         -0.46      -0.05        0.48       0.61             0.67
# 2      0.27         -0.65      -0.36       -0.34       0.35            -0.22
# 3     -0.97         -0.91      -0.67       -0.84      -0.82            -0.79
# 4     -0.67          0.64      -0.67       -0.67      -0.82            -0.79
#
#    clearances_z  blocks_z  aerials_z  fouls_z  fouled_z  nsxg_z
# 0         -0.80     -0.45      -0.23    -0.38     -0.91   -0.58
# 1          0.32     -0.45       0.21    -1.11      0.68   -0.03
# 2         -0.80     -0.45      -0.89     0.72      0.04   -0.66
# 3         -0.64     -0.45       0.21    -1.11     -0.59   -0.77
# 4         -0.64     -0.45      -0.89    -1.11     -0.91   -0.77

# %%
# Prints no. of rows and columns of a DataFrame
df.team
# Out:
# 0          Argentina
# 1          Argentina
# 2          Argentina
# 3          Argentina
# 4          Argentina
#             ...
# 5894    West Germany
# 5895    West Germany
# 5896    West Germany
# 5897    West Germany
# 5898    West Germany
# Name: team, Length: 5899, dtype: object

# %% [markdown]
# # Indexing DataFrames with Pandas
#
# Indexing can be possible using the pandas.DataFrame.iloc method. The iloc method allows to retrieve as  many as rows and columns by position.

# %%
# prints first 5 rows and every column which replicates df.head()
df.iloc[0:5,:]
# Out:
#            player  season       team  goals_z  xg_z  crosses_z  boxtouches_z  \
# 0  Cristian Pavón    2018  Argentina    -0.42 -0.55       0.08         -0.24
# 1  Eduardo Salvio    2018  Argentina    -0.42 -0.50      -0.51          0.64
# 2      Enzo Pérez    2018  Argentina    -0.42  0.11      -0.51         -0.69
# 3  Federico Fazio    2018  Argentina    -0.42 -0.59      -0.51         -0.69
# 4   Franco Armani    2018  Argentina    -0.42 -0.59      -0.51         -0.80
#
#    passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# 0     -0.61         -0.72      -0.05        0.15       0.30            -0.79
# 1      0.02         -0.46      -0.05        0.48       0.61             0.67
# 2      0.27         -0.65      -0.36       -0.34       0.35            -0.22
# 3     -0.97         -0.91      -0.67       -0.84      -0.82            -0.79
# 4     -0.67          0.64      -0.67       -0.67      -0.82            -0.79
#
#    clearances_z  blocks_z  aerials_z  fouls_z  fouled_z  nsxg_z
# 0         -0.80     -0.45      -0.23    -0.38     -0.91   -0.58
# 1          0.32     -0.45       0.21    -1.11      0.68   -0.03
# 2         -0.80     -0.45      -0.89     0.72      0.04   -0.66
# 3         -0.64     -0.45       0.21    -1.11     -0.59   -0.77
# 4         -0.64     -0.45      -0.89    -1.11     -0.91   -0.77

# %%
# prints entire rows and columns
df.iloc[:,:]
# Out:
#                 player  season          team  goals_z  xg_z  crosses_z  \
# 0       Cristian Pavón    2018     Argentina    -0.42 -0.55       0.08
# 1       Eduardo Salvio    2018     Argentina    -0.42 -0.50      -0.51
# 2           Enzo Pérez    2018     Argentina    -0.42  0.11      -0.51
# 3       Federico Fazio    2018     Argentina    -0.42 -0.59      -0.51
# 4        Franco Armani    2018     Argentina    -0.42 -0.59      -0.51
# ...                ...     ...           ...      ...   ...        ...
# 5894        Uwe Seeler    1966  West Germany     1.28  3.01      -0.08
# 5895     Werner Krämer    1966  West Germany    -0.39 -0.63       0.46
# 5896      Willi Schulz    1966  West Germany    -0.39 -0.63      -0.35
# 5897  Wolfgang Overath    1966  West Germany    -0.39 -0.12       0.73
# 5898    Wolfgang Weber    1966  West Germany     0.45 -0.16      -0.62
#
#       boxtouches_z  passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  \
# 0            -0.24     -0.61         -0.72      -0.05        0.15       0.30
# 1             0.64      0.02         -0.46      -0.05        0.48       0.61
# 2            -0.69      0.27         -0.65      -0.36       -0.34       0.35
# 3            -0.69     -0.97         -0.91      -0.67       -0.84      -0.82
# 4            -0.80     -0.67          0.64      -0.67       -0.67      -0.82
# ...            ...       ...           ...        ...         ...        ...
# 5894          4.34      0.04         -0.65      -0.42       -0.03      -0.68
# 5895         -0.51     -1.53         -1.11      -0.60       -0.73      -1.10
# 5896         -0.67      0.49          0.41      -0.77       -0.66       1.48
# 5897          0.05      1.82          0.87       0.11        0.26       1.64
# 5898         -0.41     -0.55         -0.41      -0.60       -0.52       0.17
#
#       interceptions_z  clearances_z  blocks_z  aerials_z  fouls_z  fouled_z  \
# 0               -0.79         -0.80     -0.45      -0.23    -0.38     -0.91
# 1                0.67          0.32     -0.45       0.21    -1.11      0.68
# 2               -0.22         -0.80     -0.45      -0.89     0.72      0.04
# 3               -0.79         -0.64     -0.45       0.21    -1.11     -0.59
# 4               -0.79         -0.64     -0.45      -0.89    -1.11     -0.91
# ...               ...           ...       ...        ...      ...       ...
# 5894            -0.01         -0.63     -0.26       2.90    -0.09      2.14
# 5895            -0.85         -0.69     -0.62      -0.60    -1.21     -0.34
# 5896             0.70          2.45      3.12       0.15     0.10     -0.51
# 5897             1.49         -0.46     -0.62      -0.35     1.60      0.55
# 5898             1.77          2.05      0.46       1.65    -0.09      1.25
#
#       nsxg_z
# 0      -0.58
# 1      -0.03
# 2      -0.66
# 3      -0.77
# 4      -0.77
# ...      ...
# 5894    0.38
# 5895   -0.17
# 5896   -0.60
# 5897    0.41
# 5898   -0.86
#
# [5899 rows x 19 columns]

# %%
# prints from 5th rows and first 5 columns
df.iloc[5:,:5]
# Out:
#                  player  season          team  goals_z  xg_z
# 5       Gabriel Mercado    2018     Argentina     1.30 -0.30
# 6       Gonzalo Higuaín    2018     Argentina    -0.42  0.25
# 7     Javier Mascherano    2018     Argentina    -0.42 -0.52
# 8          Lionel Messi    2018     Argentina     1.30  3.08
# 9          Lucas Biglia    2018     Argentina    -0.42 -0.50
# ...                 ...     ...           ...      ...   ...
# 5894         Uwe Seeler    1966  West Germany     1.28  3.01
# 5895      Werner Krämer    1966  West Germany    -0.39 -0.63
# 5896       Willi Schulz    1966  West Germany    -0.39 -0.63
# 5897   Wolfgang Overath    1966  West Germany    -0.39 -0.12
# 5898     Wolfgang Weber    1966  West Germany     0.45 -0.16
#
# [5894 rows x 5 columns]

# %% [markdown]
# # Indexing Using Labels in Pandas
#
# Indexing can be worked with labels using the pandas.DataFrame.loc method, which allows to index using labels instead of positions.

# %%
# prints first five rows including 5th index and every columns of df
df.loc[0:5,:]
# Out:
#             player  season       team  goals_z  xg_z  crosses_z  boxtouches_z  \
# 0   Cristian Pavón    2018  Argentina    -0.42 -0.55       0.08         -0.24
# 1   Eduardo Salvio    2018  Argentina    -0.42 -0.50      -0.51          0.64
# 2       Enzo Pérez    2018  Argentina    -0.42  0.11      -0.51         -0.69
# 3   Federico Fazio    2018  Argentina    -0.42 -0.59      -0.51         -0.69
# 4    Franco Armani    2018  Argentina    -0.42 -0.59      -0.51         -0.80
# 5  Gabriel Mercado    2018  Argentina     1.30 -0.30       0.08         -0.35
#
#    passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# 0     -0.61         -0.72      -0.05        0.15       0.30            -0.79
# 1      0.02         -0.46      -0.05        0.48       0.61             0.67
# 2      0.27         -0.65      -0.36       -0.34       0.35            -0.22
# 3     -0.97         -0.91      -0.67       -0.84      -0.82            -0.79
# 4     -0.67          0.64      -0.67       -0.67      -0.82            -0.79
# 5      1.00         -0.20      -0.36        0.15       1.43             0.79
#
#    clearances_z  blocks_z  aerials_z  fouls_z  fouled_z  nsxg_z
# 0         -0.80     -0.45      -0.23    -0.38     -0.91   -0.58
# 1          0.32     -0.45       0.21    -1.11      0.68   -0.03
# 2         -0.80     -0.45      -0.89     0.72      0.04   -0.66
# 3         -0.64     -0.45       0.21    -1.11     -0.59   -0.77
# 4         -0.64     -0.45      -0.89    -1.11     -0.91   -0.77
# 5          0.64      0.73      -0.01     1.81      0.68   -0.47

# %%
# prints from 5th rows onwards and entire columns
df.loc[5:,:]
# Out:
#                  player  season          team  goals_z  xg_z  crosses_z  \
# 5       Gabriel Mercado    2018     Argentina     1.30 -0.30       0.08
# 6       Gonzalo Higuaín    2018     Argentina    -0.42  0.25      -0.51
# 7     Javier Mascherano    2018     Argentina    -0.42 -0.52      -0.51
# 8          Lionel Messi    2018     Argentina     1.30  3.08       0.66
# 9          Lucas Biglia    2018     Argentina    -0.42 -0.50      -0.51
# ...                 ...     ...           ...      ...   ...        ...
# 5894         Uwe Seeler    1966  West Germany     1.28  3.01      -0.08
# 5895      Werner Krämer    1966  West Germany    -0.39 -0.63       0.46
# 5896       Willi Schulz    1966  West Germany    -0.39 -0.63      -0.35
# 5897   Wolfgang Overath    1966  West Germany    -0.39 -0.12       0.73
# 5898     Wolfgang Weber    1966  West Germany     0.45 -0.16      -0.62
#
#       boxtouches_z  passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  \
# 5            -0.35      1.00         -0.20      -0.36        0.15       1.43
# 6            -0.02     -0.77         -1.10      -0.36       -0.67      -0.82
# 7            -0.80      3.25          0.51       0.26        1.63       3.71
# 8             1.30      1.17          0.32       6.76        2.12       2.15
# 9            -0.35     -0.58         -0.91      -0.67       -0.84      -0.11
# ...            ...       ...           ...        ...         ...        ...
# 5894          4.34      0.04         -0.65      -0.42       -0.03      -0.68
# 5895         -0.51     -1.53         -1.11      -0.60       -0.73      -1.10
# 5896         -0.67      0.49          0.41      -0.77       -0.66       1.48
# 5897          0.05      1.82          0.87       0.11        0.26       1.64
# 5898         -0.41     -0.55         -0.41      -0.60       -0.52       0.17
#
#       interceptions_z  clearances_z  blocks_z  aerials_z  fouls_z  fouled_z  \
# 5                0.79          0.64      0.73      -0.01     1.81      0.68
# 6               -0.79         -0.64     -0.45      -0.67    -0.38     -0.59
# 7                2.75          0.80     -0.45      -0.01     4.37      1.32
# 8               -0.79         -0.80     -0.45      -0.89     0.35      4.49
# 9               -0.79         -0.80     -0.45      -0.45    -1.11     -0.59
# ...               ...           ...       ...        ...      ...       ...
# 5894            -0.01         -0.63     -0.26       2.90    -0.09      2.14
# 5895            -0.85         -0.69     -0.62      -0.60    -1.21     -0.34
# 5896             0.70          2.45      3.12       0.15     0.10     -0.51
# 5897             1.49         -0.46     -0.62      -0.35     1.60      0.55
# 5898             1.77          2.05      0.46       1.65    -0.09      1.25
#
#       nsxg_z
# 5      -0.47
# 6      -0.31
# 7      -0.31
# 8       4.55
# 9      -0.69
# ...      ...
# 5894    0.38
# 5895   -0.17
# 5896   -0.60
# 5897    0.41
# 5898   -0.86
#
# [5894 rows x 19 columns]

# %%
# Prints the first 5 rows of Time period
# value
df.loc[:5,"team"]
# Out:
# 5    Argentina
# Name: team, dtype: object

# %% [markdown]
# # DataFrame Math with Pandas
#
# Computation of data frames can be done by using Statistical Functions of pandas tools.

# %%
# computes various summary statistics, excluding NaN values
df.describe()
# Out:
#             season      goals_z         xg_z    crosses_z  boxtouches_z  \
# count  5894.000000  5894.000000  5894.000000  5894.000000   5894.000000
# mean   1996.424839     0.000400     0.000521     0.000560     -0.000231
# std      15.308936     0.999255     0.999186     0.999403      0.999378
# min    1966.000000    -0.500000    -0.720000    -0.750000     -0.810000
# 25%    1986.000000    -0.420000    -0.590000    -0.570000     -0.700000
# 50%    1998.000000    -0.410000    -0.380000    -0.510000     -0.370000
# 75%    2010.000000    -0.390000     0.200000     0.200000      0.270000
# max    2018.000000    10.120000     8.600000     8.080000      7.510000
#
#           passes_z  progpasses_z    takeons_z   progruns_z    tackles_z  \
# count  5894.000000   5894.000000  5894.000000  5894.000000  5894.000000
# mean      0.000336      0.000412    -0.000299     0.000141     0.000165
# std       0.999147      0.999205     0.999483     0.999281     0.999114
# min      -1.650000     -1.320000    -0.910000    -1.180000    -1.100000
# 25%      -0.800000     -0.800000    -0.680000    -0.730000    -0.770000
# 50%      -0.170000     -0.260000    -0.320000    -0.290000    -0.300000
# 75%       0.630000      0.550000     0.340000     0.460000     0.470000
# max       5.120000      5.530000     9.180000     7.340000     6.660000
#
#        interceptions_z  clearances_z     blocks_z    aerials_z      fouls_z  \
# count       5894.00000   5894.000000  5894.000000  5894.000000  5894.000000
# mean           0.00047      0.000747    -0.000051     0.000663     0.000295
# std            0.99903      0.998850     0.999422     0.998946     0.999113
# min           -1.03000     -0.800000    -0.620000    -0.890000    -1.280000
# 25%           -0.79000     -0.680000    -0.560000    -0.690000    -0.790000
# 50%           -0.29000     -0.420000    -0.480000    -0.310000    -0.180000
# 75%            0.46000      0.260000     0.230000     0.280000     0.570000
# max            5.74000      5.780000    10.910000    10.220000     6.860000
#
#           fouled_z       nsxg_z
# count  5894.000000  5894.000000
# mean      0.000241     0.000567
# std       0.999106     0.999070
# min      -1.100000    -1.010000
# 25%      -0.710000    -0.730000
# 50%      -0.280000    -0.340000
# 75%       0.450000     0.380000
# max       6.770000     7.280000

# %%
# for computing correlations
df.corr()
# Out:
#                    season   goals_z      xg_z  crosses_z  boxtouches_z  \
# season           1.000000  0.000325  0.000935   0.001084      0.000612
# goals_z          0.000325  1.000000  0.715138   0.136391      0.549366
# xg_z             0.000935  0.715138  1.000000   0.200574      0.732087
# crosses_z        0.001084  0.136391  0.200574   1.000000      0.169506
# boxtouches_z     0.000612  0.549366  0.732087   0.169506      1.000000
# passes_z         0.000489  0.038462  0.095536   0.314797      0.017529
# progpasses_z     0.000390 -0.096798 -0.113306   0.284971     -0.193297
# takeons_z        0.000038  0.283605  0.369178   0.384047      0.380792
# progruns_z       0.000242  0.181252  0.266952   0.442830      0.248559
# tackles_z        0.000125 -0.003334  0.012886   0.174465     -0.010861
# interceptions_z  0.000433 -0.039785 -0.025664   0.128511     -0.051744
# clearances_z     0.000827 -0.132142 -0.172471  -0.096036     -0.177855
# blocks_z         0.000470 -0.048069 -0.071683  -0.071480     -0.081958
# aerials_z        0.000308  0.125244  0.192626  -0.054545      0.340473
# fouls_z          0.000801  0.139186  0.215205   0.151336      0.254964
# fouled_z         0.000400  0.295654  0.395925   0.315579      0.426623
# nsxg_z           0.000638  0.347204  0.470131   0.763123      0.494590
#
#                  passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  \
# season           0.000489      0.000390   0.000038    0.000242   0.000125
# goals_z          0.038462     -0.096798   0.283605    0.181252  -0.003334
# xg_z             0.095536     -0.113306   0.369178    0.266952   0.012886
# crosses_z        0.314797      0.284971   0.384047    0.442830   0.174465
# boxtouches_z     0.017529     -0.193297   0.380792    0.248559  -0.010861
# passes_z         1.000000      0.771121   0.306066    0.590747   0.625188
# progpasses_z     0.771121      1.000000   0.108396    0.383445   0.410589
# takeons_z        0.306066      0.108396   1.000000    0.624111   0.196332
# progruns_z       0.590747      0.383445   0.624111    1.000000   0.384203
# tackles_z        0.625188      0.410589   0.196332    0.384203   1.000000
# interceptions_z  0.631912      0.437188   0.138044    0.353092   0.638681
# clearances_z     0.335924      0.334164  -0.133754    0.079318   0.336783
# blocks_z         0.333377      0.236918  -0.073030    0.123299   0.326131
# aerials_z        0.202838      0.087295   0.022519    0.089545   0.196348
# fouls_z          0.371574      0.147206   0.247957    0.283354   0.409857
# fouled_z         0.346384      0.121771   0.532048    0.455477   0.250464
# nsxg_z           0.389372      0.229182   0.589709    0.561033   0.195301
#
#                  interceptions_z  clearances_z  blocks_z  aerials_z   fouls_z  \
# season                  0.000433      0.000827  0.000470   0.000308  0.000801
# goals_z                -0.039785     -0.132142 -0.048069   0.125244  0.139186
# xg_z                   -0.025664     -0.172471 -0.071683   0.192626  0.215205
# crosses_z               0.128511     -0.096036 -0.071480  -0.054545  0.151336
# boxtouches_z           -0.051744     -0.177855 -0.081958   0.340473  0.254964
# passes_z                0.631912      0.335924  0.333377   0.202838  0.371574
# progpasses_z            0.437188      0.334164  0.236918   0.087295  0.147206
# takeons_z               0.138044     -0.133754 -0.073030   0.022519  0.247957
# progruns_z              0.353092      0.079318  0.123299   0.089545  0.283354
# tackles_z               0.638681      0.336783  0.326131   0.196348  0.409857
# interceptions_z         1.000000      0.460119  0.415546   0.261775  0.368237
# clearances_z            0.460119      1.000000  0.560723   0.434955  0.218839
# blocks_z                0.415546      0.560723  1.000000   0.278730  0.188636
# aerials_z               0.261775      0.434955  0.278730   1.000000  0.321354
# fouls_z                 0.368237      0.218839  0.188636   0.321354  1.000000
# fouled_z                0.207080     -0.012848  0.020941   0.203090  0.383258
# nsxg_z                  0.128281     -0.167801 -0.079140   0.051230  0.240708
#
#                  fouled_z    nsxg_z
# season           0.000400  0.000638
# goals_z          0.295654  0.347204
# xg_z             0.395925  0.470131
# crosses_z        0.315579  0.763123
# boxtouches_z     0.426623  0.494590
# passes_z         0.346384  0.389372
# progpasses_z     0.121771  0.229182
# takeons_z        0.532048  0.589709
# progruns_z       0.455477  0.561033
# tackles_z        0.250464  0.195301
# interceptions_z  0.207080  0.128281
# clearances_z    -0.012848 -0.167801
# blocks_z         0.020941 -0.079140
# aerials_z        0.203090  0.051230
# fouls_z          0.383258  0.240708
# fouled_z         1.000000  0.495721
# nsxg_z           0.495721  1.000000

# %%
# computes numerical data ranks
df.rank()
# Out:
#       player  season    team  goals_z    xg_z  crosses_z  boxtouches_z  \
# 5     1761.0  5617.0   193.5   5243.5  3291.5     4171.0        3004.5
# 6     1959.0  5617.0   193.5   1746.5  4499.0     3075.0        3893.5
# 7     2498.5  5617.0   193.5   1746.5  2189.5     3075.0         251.5
# 8     3306.5  5617.0   193.5   5243.5  5761.0     4963.0        5279.0
# 9     3342.5  5617.0   193.5   1746.5  2320.0     3075.0        3004.5
# ...      ...     ...     ...      ...     ...        ...           ...
# 5894  5496.5   127.5  5757.5   5225.0  5756.0     3798.0        5864.0
# 5895  5638.0   127.5  5757.5   4190.0  1049.5     4703.5        2357.0
# 5896  5653.5   127.5  5757.5   4190.0  1049.5     3322.5        1630.0
# 5897  5704.0   127.5  5757.5   4190.0  3792.5     4987.5        4017.0
# 5898  5708.5   127.5  5757.5   4806.0  3703.0      902.5        2807.0
#
#       passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  \
# 5       4918.0        3080.0     2816.0      3913.0     5326.5
# 6       1544.0         329.5     2816.0      1768.5     1257.5
# 7       5864.5        4336.0     4320.5      5472.0     5858.0
# 8       5107.0        4061.5     5890.0      5630.0     5645.5
# 9       2008.5        1124.0     1849.5      1064.0     3403.0
# ...        ...           ...        ...         ...        ...
# 5894    3389.5        1961.5     2580.5      3552.5     1776.5
# 5895      20.5         275.0     2249.0      1511.0       22.0
# 5896    4205.5        4195.5      456.5      1815.0     5361.0
# 5897    5583.5        4781.0     4025.0      4106.0     5444.0
# 5898    2068.0        2603.5     2249.0      2238.0     3964.0
#
#       interceptions_z  clearances_z  blocks_z  aerials_z  fouls_z  fouled_z  \
# 5              4815.0        4783.0    4978.5     3800.5   5578.0    4718.0
# 6              1409.0        1647.5    3471.0     1503.0   2511.0    1978.5
# 7              5763.5        4912.5    3471.0     3800.5   5884.5    5313.0
# 8              1409.0          65.0    3471.0       48.5   4043.0    5875.0
# 9              1409.0          65.0    3471.0     2475.5    733.0    1978.5
# ...               ...           ...       ...        ...      ...       ...
# 5894           3633.0        1714.5    3762.0     5750.0   3123.5    5652.5
# 5895            896.5        1329.0      71.0     2061.0    243.0    2724.5
# 5896           4716.5        5659.0    5780.0     4193.5   3610.0    2226.0
# 5897           5373.5        2758.0      71.0     2758.0   5456.5    4543.5
# 5898           5504.5        5554.0    4716.0     5522.0   3123.5    5283.0
#
#       nsxg_z
# 5     2519.5
# 6     3022.5
# 7     3022.5
# 8     5867.0
# 9     1634.0
# ...      ...
# 5894  4412.0
# 5895  3398.0
# 5896  2015.5
# 5897  4472.5
# 5898   466.5
#
# [5894 rows x 19 columns]

# %% [markdown]
# # Pandas Plotting
#
# Plots in these examples are made using standard convention for referencing the matplotlib API which provides the basics in pandas to easily create decent looking plots.

# %%
# import the required module
import matplotlib.pyplot as plt

# plot a histogram
df['goals_z'].hist()

# %%
# shows presence of a lot of outliers/extreme values
df.boxplot(column='goals_z', by = 'team')

# %%
# plotting points as a scatter plot
x = df["goals_z"]
y = df["team"]
plt.scatter(x, y, label= "stars", color= "m", 
            marker= "*", s=30)
# x-axis label
plt.xlabel('goals_z')
# frequency label
plt.ylabel('team')
# function to show the plot
plt.show()
