# %% [markdown]
# # Exploratory Data Analysis in Python
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.
#
# For example using the "world_cup_comparisons.csv", which can be imported in python as:

# %%
import pandas as pd
Df = pd.read_csv("C:/Users/kandr/Desktop/PYTHON/Programming/Data Analysis/Exploratory Data Analysis in Python/world_cup_comparisons.csv")

# %% [markdown]
# - describe() function applies basic statistical computations on the dataset like extreme values, count of data points standard deviation etc. Any missing value or NaN value is automatically skipped. describe() function gives a good picture of distribution of data.

# %%
Df.describe()
# Out:
#             season      goals_z         xg_z    crosses_z  boxtouches_z  \
# count  5899.000000  5899.000000  5899.000000  5899.000000   5899.000000
# mean   1996.443126     0.000044     0.000161     0.000227     -0.000532
# std      15.315323     0.998907     0.998870     0.999068      0.999129
# min    1966.000000    -0.500000    -0.720000    -0.750000     -0.810000
# 25%    1986.000000    -0.420000    -0.590000    -0.570000     -0.700000
# 50%    1998.000000    -0.410000    -0.390000    -0.510000     -0.370000
# 75%    2010.000000    -0.390000     0.200000     0.200000      0.270000
# max    2018.000000    10.120000     8.600000     8.080000      7.510000
#
#           passes_z  progpasses_z    takeons_z   progruns_z    tackles_z  \
# count  5899.000000   5899.000000  5899.000000  5899.000000  5899.000000
# mean      0.000003      0.000056    -0.000603    -0.000066     0.000100
# std       0.998879      0.998985     0.999147     0.998987     0.998854
# ...

# %% [markdown]
#  - value_counts() can get count of each category in a categorical attributed series of values.

# %%
Df["player"].value_counts()
# Out:
# Lothar Matthäus        5
# Rafael Márquez         5
# Andoni Zubizarreta     4
# Jorge Campos           4
# Thierry Henry          4
#                       ..
# Carpeggiani            1
# Domingo Pérez          1
# André Macanga          1
# Hang Kee Choi          1
# Giourkas Seitaridis    1
# Name: player, Length: 4533, dtype: int64

# %%
Df["team"].value_counts()
# Out:
# Brazil                  234
# Argentina               229
# Italy                   228
# Spain                   219
# England                 191
#                        ...
# Angola                   16
# Israel                   15
# Iceland                  15
# United Arab Emirates     15
# Kuwait                   14
# Name: team, Length: 80, dtype: int64

# %% [markdown]
# - Boxplot is a pictorial representation of distribution of data which shows extreme values, median and quartiles.

# %%
import pandas as pd
import matplotlib.pyplot as plt
Df = pd.read_csv("C:/Users/kandr/Desktop/PYTHON/Programming/Data Analysis/Exploratory Data Analysis in Python/world_cup_comparisons.csv")
y = list(Df.goals_z)
plt.boxplot(y)
plt.show()

# %% [markdown]
# - Group helps to figure out effect of different categorical attributes on other data variables.

# %%
Df.groupby(['player', 'team']).mean()
# Out:
#                                       season  goals_z   xg_z  crosses_z  \
# player                  team
# Aaron Lawrence          Jamaica       1998.0   -0.420 -0.680     -0.660
# Aaron Lennon            England       2008.0   -0.410 -0.405     -0.345
# Aaron Mokoena           South Africa  2006.0   -0.405 -0.305     -0.540
# Aaron Mooy              Australia     2018.0   -0.420 -0.270      7.260
# Aaron Padilla Gutiérrez Mexico        1968.0   -0.390 -0.490      2.160
# ...                                      ...      ...    ...        ...
# Örjan Persson           Sweden        1972.0   -0.400 -0.470     -0.245
# Özalan Alpay            Turkey        2002.0   -0.410 -0.390     -0.560
# Øyvind Leonhardsen      Norway        1996.0   -0.405 -0.335     -0.390
# Ümit Davala             Turkey        2002.0    1.320 -0.170      0.870
# Ümit Özat               Turkey        2002.0   -0.410 -0.580     -0.560
#
# ...
